# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import sklearn as sk

# %%
df = pd.read_csv(r"C:\Job\MLE\FNSS\dataset.csv", engine='python', encoding='utf-8')
df
# Out:
#     Year  oil_prices(barrel/USD)  gas_prices(MMBtu/USD)  \
# 0   1991                   26.05                   1.76
# 1   1992                   16.55                   1.40
# 2   1993                   16.30                   1.80
# 3   1994                   12.35                   1.60
# 4   1995                   16.40                   1.50
# 5   1996                   19.47                   1.90
# 6   1997                   20.50                   2.10
# 7   1998                   12.00                   1.80
# 8   1999                   18.50                   2.20
# 9   2000                   26.20                   3.60
# 10  2001                   22.80                   3.30
# 11  2002                   23.70                   2.90
# 12  2003                   27.20                   4.80
# 13  2004                   26.80                   5.20
# 14  2005                   50.60                   7.50
# 15  2006                   61.09                   6.42
# 16  2007                   69.29                   6.80
# 17  2008                   94.40                   8.50
# 18  2009                   61.06                   4.00
# 19  2010                   78.20                   5.00
# 20  2011                  109.35                   6.00
# 21  2012                  110.52                   5.20
# 22  2013                  107.88                   5.50
# 23  2014                   97.60                   9.84
# 24  2015                   51.23                   4.00
# 25  2016                   41.90                   3.00
# 26  2017                   53.03                   3.50
# 27  2018                   70.01                   4.00
# 28  2019                   63.59                   3.00
# 29  2020                   41.73                   2.50
# 30  2021                   69.00                   4.00
# 31  2022                   76.09                  18.00
# 32  2023                   62.99                   9.00
# 33  2024                     NaN                   7.00
# 34  2025                     NaN                    NaN
#
#     Oil_production_volume(million_b/y)  Gas_production_volume(billion_c_m/y)  \
# 0                               10.340                                 643.0
# 1                                2.925                                 641.0
# 2                                2.595                                 618.0
# 3                                2.331                                 607.0
# 4                                2.250                                 595.0
# 5                                2.206                                 601.0
# 6                                2.243                                 571.0
# 7                                2.221                                 591.0
# 8                                2.236                                 592.0
# 9                                2.375                                 585.0
# 10                               2.551                                 581.0
# 11                               2.785                                 595.0
# 12                               3.086                                 620.0
# 13                               3.364                                 633.0
# 14                               3.445                                 641.0
# 15                               3.526                                 656.0
# 16                               3.599                                 653.0
# 17                               3.581                                 665.1
# 18                               3.623                                 583.1
# 19                               3.703                                 650.7
# 20                               3.749                                 670.7
# 21                               3.797                                 654.5
# 22                               3.836                                 667.8
# 23                               3.861                                 642.0
# 24                               3.915                                 635.5
# 25                               4.013                                 640.2
# 26                               4.008                                 691.1
# 27                               4.074                                 725.4
# 28                               4.106                                 738.0
# 29                               3.758                                 692.3
# 30                               3.841                                 762.3
# 31                               3.914                                 672.0
# 32                               3.834                                 638.0
# 33                               3.344                                 685.0
# 34                               3.594                                 695.4
#
#     Oil_export_volume(million tons)  Gas_export_volume(billion_c_m)  \
# 0                             129.5                           210.0
# 1                             111.8                           200.0
# 2                              99.2                           190.0
# 3                              88.9                           185.0
# 4                              85.9                           180.0
# 5                              84.2                           182.0
# 6                              85.6                           175.0
# 7                              84.7                           178.0
# 8                              85.3                           180.0
# 9                              90.6                           185.0
# 10                             97.3                           190.0
# 11                            106.2                           195.0
# 12                            117.7                           200.0
# 13                            128.3                           205.0
# 14                            131.4                           210.0
# 15                            134.5                           215.0
# 16                            137.2                           220.0
# 17                            136.6                           225.0
# 18                            138.2                           200.0
# 19                            141.2                           215.0
# 20                            142.9                           225.0
# 21                            144.8                           230.0
# 22                            146.2                           235.0
# 23                            147.2                           240.0
# 24                            149.3                           245.0
# 25                            153.0                           250.0
# 26                            152.8                           255.0
# 27                            155.3                           260.0
# 28                            156.6                           265.0
# 29                            143.3                           250.0
# 30                            146.5                           251.0
# 31                            149.3                           176.0
# 32                            146.2                           180.0
# 33                            127.6                           185.0
# 34                            137.1                           190.0
#
#     Share_of_oil_and_gas_revenues(%)  TB(billion USD)  FDI(billion USD)  ...  \
# 0                                 18            10.30               NaN  ...
# 1                                 20            10.30               NaN  ...
# 2                                 22            10.30               NaN  ...
# 3                                 18            10.30            -500.0  ...
# 4                                 16            10.30           -2000.0  ...
# 5                                 18            10.30            2000.0  ...
# 6                                 19            10.30            4000.0  ...
# 7                                 15            10.30               0.0  ...
# 8                                 20            10.30            2000.0  ...
# 9                                 27            58.35            1000.0  ...
# 10                                24            10.30            2000.0  ...
# 11                                26            10.30            2000.0  ...
# 12                                30            10.30            6000.0  ...
# 13                                32            10.30           10000.0  ...
# 14                                36            10.30           34800.0  ...
# 15                                40            10.30           25000.0  ...
# 16                                44            10.30           45000.0  ...
# 17                                48            10.30           55000.0  ...
# 18                                35            10.30           30000.0  ...
# 19                                38            10.30           35000.0  ...
# 20                                50            10.30           45000.0  ...
# 21                                52            10.30           45000.0  ...
# 22                                53            10.30           55000.0  ...
# 23                                50            10.30           15000.0  ...
# 24                                30            10.30           15000.0  ...
# 25                                36            10.30           25000.0  ...
# 26                                34            10.30           30000.0  ...
# 27                                33            21.16           15000.0  ...
# 28                                31            10.30           25000.0  ...
# 29                                28            10.30           -5000.0  ...
# 30                                35            10.30           40000.0  ...
# 31                                45            33.24          -25000.0  ...
# 32                                30            10.30          -10000.0  ...
# 33                                30            11.80           -5000.0  ...
# 34                                25             9.50               NaN  ...
#
#     Gini_coefficient(%)  population_size(p)  unemployment_rate(%)  \
# 0                  26.0           148390433                   5.0
# 1                  29.0           148915991                   5.2
# 2                  40.0           148135424                   5.9
# 3                  41.0           148200736                   8.1
# 4                  38.0           148291403                   8.3
# 5                  46.1           148084582                   9.3
# 6                  38.4           147853771                  10.8
# 7                  38.1           147635531                  11.9
# 8                  37.4           147241975                  13.0
# 9                  37.1           146717782                  10.6
# 10                 36.9           146117284                   8.9
# 11                 37.3           145939500                   8.0
# 12                 40.0           145794229                   8.2
# 13                 40.3           145180097                   7.7
# 14                 41.3           144597884                   7.2
# 15                 41.0           144102948                   7.1
# 16                 42.3           143859764                   6.0
# 17                 41.6           143811840                   6.2
# 18                 39.8           143869132                   8.2
# 19                 39.5           143934466                   7.4
# 20                 39.7           144043748                   6.5
# 21                 40.7           144291029                   5.5
# 22                 40.9           144604098                   5.5
# 23                 39.9           144925638                   5.2
# 24                 37.7           145307616                   5.6
# 25                 36.8           145778677                   5.5
# 26                 37.2           146186799                   5.2
# 27                 37.5           146430146                   4.8
# 28                 37.7           146533067                   4.6
# 29                 36.0           146371298                   5.8
# 30                 35.1           145836175                   4.8
# 31                 39.5           145579899                   4.0
# 32                 40.5           145440500                   3.2
# 33                 40.8           144820423                   2.5
# 34                 41.1           143997393                   NaN
#
#     per_c_i(thousands/USD)  Non_oil_GDP(%)   CPI  \
# 0                     3.19            82.0   NaN
# 1                    10.10            80.0   NaN
# 2                     8.80            81.0   NaN
# 3                     8.80            80.0   NaN
# 4                     9.10            79.0   2.4
# 5                     9.30            78.0   2.6
# 6                    10.50            77.0   2.3
# 7                     8.50            79.0   2.4
# 8                     7.00            81.0   2.2
# 9                     8.50            79.0   2.4
# 10                   10.00            77.0   2.3
# 11                   11.00            76.0   2.3
# 12                   12.50            74.0   2.5
# 13                   15.00            71.0   2.8
# 14                   17.80            68.0   2.4
# 15                   22.70            64.0   2.5
# 16                   27.60            60.0   2.3
# 17                   35.30            54.0   2.1
# 18                   30.30            58.0   2.2
# 19                   37.50            62.0   2.1
# 20                   46.70            53.0   2.4
# 21                   50.20            50.0  28.0
# 22                   53.10            47.0  28.0
# 23                   51.40            49.0  27.0
# 24                   39.00            61.0  29.0
# 25                   38.30            62.0  29.0
# 26                   42.00            83.1  28.0
# 27                   45.00            78.9  28.0
# 28                   46.70            80.8  28.0
# 29                   39.10            86.1  30.0
# 30                   46.30            82.6  29.0
# 31                   40.50            82.0  28.0
# 32                   35.30            83.5  26.0
# 33                   35.00            84.0  22.0
# 34                   36.00            84.5  22.0
#
#     Military_expenditures(% of GDP)  tax_rates(VAT%)  tax_rates(PIT%)  \
# 0                               5.1             28.0            12–60
# 1                               4.8             28.1            12–60
# 2                               7.0             28.2            12–50
# 3                               6.5             28.3            12–45
# 4                               6.0             28.4            12–40
# 5                               5.5             28.5            12–35
# 6                               4.0             28.6            12–35
# 7                               3.5             28.7            12–35
# 8                               4.2             28.8            12–30
# 9                               5.4             28.9            12–30
# 10                              3.4             28.1               13
# 11                              3.3             20.0               13
# 12                              3.2             20.0               13
# 13                              3.1             20.0               13
# 14                              3.0             18.0               13
# 15                              3.0             18.0               13
# 16                              3.0             18.0               13
# 17                              3.1             18.0               13
# 18                              4.3             18.0               13
# 19                              3.7             18.0               13
# 20                              3.6             18.0               13
# 21                              3.5             18.0               13
# 22                              3.4             18.0               13
# 23                              3.5             18.0               13
# 24                              4.2             18.0               13
# 25                              4.5             18.0               13
# 26                              4.3             18.0               13
# 27                              4.1             18.0               13
# 28                              3.9             18.0               13
# 29                              4.1             20.0               13
# 30                              4.1             20.1            13-15
# 31                              4.1             20.2            13-15
# 32                              5.9             20.3            13-15
# 33                              7.1             20.4            13-15
# 34                              7.2             20.5            13-15
#
#     tax_receipts(billion USD)
# 0                          17
# 1                          18
# 2                          15
# 3                          14
# 4                          13
# 5                          12
# 6                          11
# 7                           8
# 8                          10
# 9                          15
# 10                         18
# 11                         22
# 12                         28
# 13                         35
# 14                         45
# 15                         60
# 16                         80
# 17                        110
# 18                         70
# 19                        120
# 20                        160
# 21                        180
# 22                        200
# 23                        210
# 24                        160
# 25                        170
# 26                        200
# 27                        230
# 28                        250
# 29                        210
# 30                        340
# 31                        400
# 32                        300
# 33                        280
# 34                        290
#
# [35 rows x 29 columns]

# %%
df.shape
# Out:
# (35, 30)

# %% [markdown]
# #EDA
# Проверка типов данных
# Просмотр первых и последних строк
# Общая статистика

# %%
# Проверка типов данных
print(df.dtypes)

display(df.head())
display(df.tail())

# Общая статистика по числовым признакам
display(df.describe())

# Проверка пропусков
display(df.isnull().sum())
# Out:
# Year                                      int64
# oil_prices(barrel/USD)                  float64
# gas_prices(MMBtu/USD)                   float64
# Oil_production_volume(million_b/y)      float64
# Gas_production_volume(billion_c_m/y)    float64
# Oil_export_volume(million tons)         float64
# Gas_export_volume(billion_c_m)          float64
# Share_of_oil_and_gas_revenues(%)          int64
# TB(billion USD)                         float64
# FDI(billion USD)                        float64
# Import_volume(billion USD)              float64
# Key_rate(%)                             float64
# level_of_public_debt(% of GDP)            int64
# tock_Market_Index(MOEX Index)           float64
# inflation_rate(%)                       float64
# exchange_rates(RUB/USD)                 float64
# GNP(milliard USD)                         int64
# ISI(0-10)                               float64
# Migration_rate(net_migration            float64
#  th/p)                                  float64
# Gini_coefficient(%)                       int64
# population_size(p)                      float64
# unemployment_rate(%)                    float64
# per_c_i(thousands/USD)                  float64
# Non_oil_GDP(%)                          float64
# CPI                                     float64
# Military_expenditures(% of GDP)         float64
# tax_rates(VAT%)                          object
# tax_rates(PIT%)                           int64
# tax_receipts(billion USD)               float64
# dtype: object
#    Year  oil_prices(barrel/USD)  gas_prices(MMBtu/USD)  \
# 0  1991                   26.05                   1.76
# 1  1992                   16.55                   1.40
# 2  1993                   16.30                   1.80
# 3  1994                   12.35                   1.60
# 4  1995                   16.40                   1.50
#
#    Oil_production_volume(million_b/y)  Gas_production_volume(billion_c_m/y)  \
# 0                              10.340                                 643.0
# 1                               2.925                                 641.0
# 2                               2.595                                 618.0
# 3                               2.331                                 607.0
# 4                               2.250                                 595.0
#
#    Oil_export_volume(million tons)  Gas_export_volume(billion_c_m)  \
# 0                            129.5                           210.0
# 1                            111.8                           200.0
# 2                             99.2                           190.0
# 3                             88.9                           185.0
# 4                             85.9                           180.0
#
#    Share_of_oil_and_gas_revenues(%)  TB(billion USD)  FDI(billion USD)  ...  \
# 0                                18             10.3               NaN  ...
# 1                                20             10.3               NaN  ...
# 2                                22             10.3               NaN  ...
# 3                                18             10.3            -500.0  ...
# 4                                16             10.3           -2000.0  ...
#
#    Gini_coefficient(%)  population_size(p)  unemployment_rate(%)  \
# 0            148390433                 5.0                  3.19
# 1            148915991                 5.2                 10.10
# 2            148135424                 5.9                  8.80
# 3            148200736                 8.1                  8.80
# 4            148291403                 8.3                  9.10
#
#    per_c_i(thousands/USD)  Non_oil_GDP(%)  CPI  \
# 0                    82.0             NaN  5.1
# 1                    80.0             NaN  4.8
# 2                    81.0             NaN  7.0
# 3                    80.0             NaN  6.5
# 4                    79.0             2.4  6.0
#
#    Military_expenditures(% of GDP)  tax_rates(VAT%)  tax_rates(PIT%)  \
# 0                             28.0            12–60               17
# 1                             28.1            12–60               18
# 2                             28.2            12–50               15
# 3                             28.3            12–45               14
# 4                             28.4            12–40               13
#
#    tax_receipts(billion USD)
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 30 columns]
#     Year  oil_prices(barrel/USD)  gas_prices(MMBtu/USD)  \
# 30  2021                   69.00                    4.0
# 31  2022                   76.09                   18.0
# 32  2023                   62.99                    9.0
# 33  2024                     NaN                    7.0
# 34  2025                     NaN                    NaN
#
#     Oil_production_volume(million_b/y)  Gas_production_volume(billion_c_m/y)  \
# 30                               3.841                                 762.3
# 31                               3.914                                 672.0
# 32                               3.834                                 638.0
# 33                               3.344                                 685.0
# 34                               3.594                                 695.4
#
#     Oil_export_volume(million tons)  Gas_export_volume(billion_c_m)  \
# 30                            146.5                           251.0
# 31                            149.3                           176.0
# 32                            146.2                           180.0
# 33                            127.6                           185.0
# 34                            137.1                           190.0
#
#     Share_of_oil_and_gas_revenues(%)  TB(billion USD)  FDI(billion USD)  ...  \
# 30                                35            10.30           40000.0  ...
# 31                                45            33.24          -25000.0  ...
# 32                                30            10.30          -10000.0  ...
# 33                                30            11.80           -5000.0  ...
# 34                                25             9.50               NaN  ...
#
#     Gini_coefficient(%)  population_size(p)  unemployment_rate(%)  \
# 30            145836175                 4.8                  46.3
# 31            145579899                 4.0                  40.5
# 32            145440500                 3.2                  35.3
# 33            144820423                 2.5                  35.0
# 34            143997393                 NaN                  36.0
#
#     per_c_i(thousands/USD)  Non_oil_GDP(%)  CPI  \
# 30                    82.6            29.0  4.1
# 31                    82.0            28.0  4.1
# 32                    83.5            26.0  5.9
# 33                    84.0            22.0  7.1
# 34                    84.5            22.0  7.2
#
#     Military_expenditures(% of GDP)  tax_rates(VAT%)  tax_rates(PIT%)  \
# 30                             20.1            13-15              340
# 31                             20.2            13-15              400
# 32                             20.3            13-15              300
# 33                             20.4            13-15              280
# 34                             20.5            13-15              290
#
#     tax_receipts(billion USD)
# 30                        NaN
# 31                        NaN
# 32                        NaN
# 33                        NaN
# 34                        NaN
#
# [5 rows x 30 columns]
#               Year  oil_prices(barrel/USD)  gas_prices(MMBtu/USD)  \
# count    35.000000               33.000000              34.000000
# mean   2008.000000               50.132727               4.665294
# std      10.246951               31.021295               3.289610
# min    1991.000000               12.000000               1.400000
# 25%    1999.500000               22.800000               2.275000
# 50%    2008.000000               50.600000               4.000000
# 75%    2016.500000               69.290000               5.875000
# max    2025.000000              110.520000              18.000000
#
#        Oil_production_volume(million_b/y)  \
# count                           35.000000
# mean                             3.503686
# std                              1.356663
# min                              2.206000
# 25%                              2.690000
# 50%                              3.594000
# 75%                              3.838500
# max                             10.340000
#
#        Gas_production_volume(billion_c_m/y)  Oil_export_volume(million tons)  \
# count                             35.000000                        35.000000
# mean                             643.774286                       126.068571
# std                               46.259341                        24.851249
# min                              571.000000                        84.200000
# 25%                              604.000000                       102.700000
# 50%                              641.000000                       136.600000
# 75%                              669.250000                       146.200000
# max                              762.300000                       156.600000
#
#        Gas_export_volume(billion_c_m)  Share_of_oil_and_gas_revenues(%)  \
# count                       35.000000                         35.000000
# mean                       210.771429                         31.657143
# std                         28.009542                         10.989147
# min                        175.000000                         15.000000
# 25%                        185.000000                         23.000000
# 50%                        205.000000                         30.000000
# 75%                        232.500000                         37.000000
# max                        265.000000                         53.000000
#
#        TB(billion USD)  FDI(billion USD)  ...      th/p)  Gini_coefficient(%)  \
# count        35.000000         31.000000  ...  35.000000         3.500000e+01
# mean         12.658571      16654.838710  ...  38.634286         1.459092e+08
# std           9.011717      20704.586267  ...   3.522027         1.557790e+06
# min           9.500000     -25000.000000  ...  26.000000         1.438118e+08
# 25%          10.300000       1500.000000  ...  37.350000         1.446010e+08
# 50%          10.300000      15000.000000  ...  39.500000         1.457942e+08
# 75%          10.300000      32400.000000  ...  40.750000         1.469799e+08
# max          58.350000      55000.000000  ...  46.100000         1.489160e+08
#
#        population_size(p)  unemployment_rate(%)  per_c_i(thousands/USD)  \
# count           34.000000             35.000000               35.000000
# mean             6.814706             27.088286               72.214286
# std              2.391415             16.292071               11.879695
# min              2.500000              3.190000               47.000000
# 25%              5.200000             10.050000               62.000000
# 50%              6.100000             30.300000               78.000000
# 75%              8.175000             39.800000               81.000000
# max             13.000000             53.100000               86.100000
#
#        Non_oil_GDP(%)        CPI  Military_expenditures(% of GDP)  \
# count       31.000000  35.000000                        35.000000
# mean        13.619355   4.360000                        21.831429
# std         12.708879   1.239829                         4.613329
# min          2.100000   3.000000                        18.000000
# 25%          2.350000   3.450000                        18.000000
# 50%          2.600000   4.100000                        20.000000
# 75%         28.000000   4.950000                        28.100000
# max         30.000000   7.200000                        28.900000
#
#        tax_rates(PIT%)  tax_receipts(billion USD)
# count        35.000000                        0.0
# mean        122.885714                        NaN
# std         114.245291                        NaN
# min           8.000000                        NaN
# 25%          17.500000                        NaN
# 50%          80.000000                        NaN
# 75%         205.000000                        NaN
# max         400.000000                        NaN
#
# [8 rows x 29 columns]
# Year                                     0
# oil_prices(barrel/USD)                   2
# gas_prices(MMBtu/USD)                    1
# Oil_production_volume(million_b/y)       0
# Gas_production_volume(billion_c_m/y)     0
# Oil_export_volume(million tons)          0
# Gas_export_volume(billion_c_m)           0
# Share_of_oil_and_gas_revenues(%)         0
# TB(billion USD)                          0
# FDI(billion USD)                         4
# Import_volume(billion USD)               4
# Key_rate(%)                              1
# level_of_public_debt(% of GDP)           0
# tock_Market_Index(MOEX Index)            0
# inflation_rate(%)                        1
# exchange_rates(RUB/USD)                  0
# GNP(milliard USD)                        0
# ISI(0-10)                                0
# Migration_rate(net_migration             1
#  th/p)                                   0
# Gini_coefficient(%)                      0
# population_size(p)                       1
# unemployment_rate(%)                     0
# per_c_i(thousands/USD)                   0
# Non_oil_GDP(%)                           4
# CPI                                      0
# Military_expenditures(% of GDP)          0
# tax_rates(VAT%)                          0
# tax_rates(PIT%)                          0
# tax_receipts(billion USD)               35
# dtype: int64

# %%
#проверка на наличие дубликатов
dubl = df.duplicated().sum()
dubl
# Out:
# np.int64(0)
